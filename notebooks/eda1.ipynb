# %%
from ds340w.data.load_data import load_san_juan_data

nodes, edges, local_population = load_san_juan_data()

# %%
local_population.head()
# Out:
#                 h3  population  \
# 0  884cee7b6bfffff         1.0
# 1  884cee7b69fffff         1.0
# 2  884cee7b67fffff      1499.0
# 3  884cee7b65fffff        96.0
# 4  884cee7b61fffff       379.0
#
#                                             geometry
# 0  POLYGON ((-7358611.322 2089670.032, -7358237.4...
# 1  POLYGON ((-7359113.052 2090231.787, -7358739.1...
# 2  POLYGON ((-7359732.872 2088598.627, -7359359.0...
# 3  POLYGON ((-7360234.519 2089160.394, -7359860.7...
# 4  POLYGON ((-7359422.965 2089415.217, -7359049.1...
